# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_paths = {
    "caso_1": "data/bench_fase_a_summary.csv",
    "caso_2": "data/bench_fase_b_summary.csv",
    "caso_3": "data/bench_fase_c_summary.csv"
}

cores = ["#094c90", "#90091d"]
